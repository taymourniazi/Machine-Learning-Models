# %% [markdown]
# # Random Selection

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
## Importing the dataset
dataset = pd.read_csv('Ads_CTR_Optimisation.csv')

# %% [markdown]
# ## Implementing Random Selection

# %%
import random
N = 10000
d = 10
ads_selected = []
total_reward = 0
for n in range(0, N):
    ad = random.randrange(d)
    ads_selected.append(ad)
    reward = dataset.values[n, ad]
    total_reward = total_reward + reward

# %%
total_reward
# Out:
# 1204

# %%
import random
N = 10000
d = 10
ads_selected = []
total_reward = 0
for n in range(0, N):
    ad = random.randrange(d)
    ads_selected.append(ad)
    reward = dataset.values[n, ad]
    total_reward = total_reward + reward

# %%
total_reward
# Out:
# 1246

# %%
import random
N = 10000
d = 10
ads_selected = []
total_reward = 0
for n in range(0, N):
    ad = random.randrange(d)
    ads_selected.append(ad)
    reward = dataset.values[n, ad]
    total_reward = total_reward + reward

# %%
total_reward
# Out:
# 1218

# %% [markdown]
# ### Therefore it is assumed that through ranom selection the total reward is in between 1100 to 1300

# %%
# Visualising the results
# %matplotlib notebook
plt.hist(ads_selected)
plt.title('Histogram of ads selections')
plt.xlabel('Ads')
plt.ylabel('Number of times each ad was selected')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Hence, It is a uniform distribution of data points

# %% [markdown]
# # Now we will explore the Upper confidence bound how it perform (whether it is decreasing or increasing the total rewards)
